# %%
from io import StringIO
import pandas as pd
import datacompy
import os

# %%
os.chdir("C:/Users/lmumelo/OneDrive - Kemri Wellcome Trust/shinyup/data")

# %%
df1 = pd.read_csv("CIN_DD_rev2.csv")
df2 = pd.read_csv("CIN_DD_rev3.csv")

# %%
df1.head()
# Out:
#   Variable / Field Name Form Name Section Header Field Type  \
# 0                    id   biodata            NaN       text
# 1               hosp_id   biodata            NaN   dropdown
# 2                 depid   biodata            NaN       text
# 3            date_today   biodata            NaN       text
# 4                  ipno   biodata            NaN       text
#
#             Field Label            Choices, Calculations, OR Slider Labels  \
# 0             Unique ID                                                NaN
# 1           Hospital ID  51, Kiambu DH |52, Machakos |53, Mama Lucy Kay...
# 2  Data Entry Person ID                                                NaN
# 3          Today's Date                                                NaN
# 4         Patients IPNO                                                NaN
#
#                                           Field Note  \
# 0  Use format [hosp id][record id] - eg.5100001 f...
# ...

# %%
df1.describe()
# Out:
#        Text Validation Min  Text Validation Max  Identifier?  \
# count            11.000000         1.200000e+01          0.0
# mean           4551.454545         1.667441e+05          NaN
# std           15073.579173         5.773259e+05          NaN
# min               0.000000         5.000000e+00          NaN
# 25%               0.500000         2.625000e+01          NaN
# 50%               3.000000         7.950000e+01          NaN
# 75%              15.000000         1.300000e+02          NaN
# max           50000.000000         2.000000e+06          NaN
#
#        Question Number (surveys only)  Matrix Group Name  Matrix Ranking?  \
# count                             0.0                0.0              0.0
# mean                              NaN                NaN              NaN
# std                               NaN                NaN              NaN
# min                               NaN                NaN              NaN
# ...

# %%
# df2.head()

# %%
df2.describe()
# Out:
#        Text Validation Min  Text Validation Max  Identifier?  \
# count         1.200000e+01         1.300000e+01          0.0
# mean          4.291722e+05         7.693022e+05          NaN
# std           1.471000e+06         2.241768e+06          NaN
# min           0.000000e+00         5.000000e+00          NaN
# 25%           7.500000e-01         2.800000e+01          NaN
# 50%           6.500000e+00         1.000000e+02          NaN
# 75%           2.000000e+01         1.600000e+02          NaN
# max           5.100000e+06         8.000000e+06          NaN
#
#        Question Number (surveys only)  Matrix Group Name  Matrix Ranking?  \
# count                             0.0                0.0              0.0
# mean                              NaN                NaN              NaN
# std                               NaN                NaN              NaN
# min                               NaN                NaN              NaN
# ...

# %%
print('Columns for Old CSV file: {}'.format(df1.columns))
print(' Columns for New CSV file: {}'.format(df2.columns))
# Out:
# Columns for Old CSV file: Index(['Variable / Field Name', 'Form Name', 'Section Header', 'Field Type',
#        'Field Label', 'Choices, Calculations, OR Slider Labels', 'Field Note',
#        'Text Validation Type OR Show Slider Number', 'Text Validation Min',
#        'Text Validation Max', 'Identifier?',
#        'Branching Logic (Show field only if...)', 'Required Field?',
#        'Custom Alignment', 'Question Number (surveys only)',
#        'Matrix Group Name', 'Matrix Ranking?', 'Field Annotation'],
#       dtype='object')
#  Columns for New CSV file: Index(['Variable / Field Name', 'Form Name', 'Section Header', 'Field Type',
#        'Field Label', 'Choices, Calculations, OR Slider Labels', 'Field Note',
#        'Text Validation Type OR Show Slider Number', 'Text Validation Min',
#        'Text Validation Max', 'Identifier?',
#        'Branching Logic (Show field only if...)', 'Required Field?',
#        'Custom Alignment', 'Question Number (surveys only)',
# ...

# %%
columnA = df1.columns
columnB = df2.columns

# %%
for column in columnA:
    if column in columnB:
        print("These columns exist in both files")
# Out:
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files
# These columns exist in both files

# %%
df1.equals(df2)
# Out:
# False

# %%
df2.values
# Out:
# array([['id', 'biodata', nan, ..., nan, nan, nan],
#        ['hosp_id', 'biodata', nan, ..., nan, nan, nan],
#        ['depid', 'biodata', nan, ..., nan, nan, nan],
#        ...,
#        ['dsc_rx5', 'discharge_information', nan, ..., nan, nan, nan],
#        ['dsc_rx_other1', 'discharge_information', nan, ..., nan, nan,
#         nan],
#        ['dsc_rx_other2', 'discharge_information', nan, ..., nan, nan,
#         nan]], dtype=object)

# %%
comparison_values = df1.fillna(0).isin(df2.fillna(0)) 
print (comparison_values)
# Out:
#      Variable / Field Name  Form Name  Section Header  Field Type  \
# 0                     True       True            True        True
# 1                     True       True            True        True
# 2                     True       True            True        True
# 3                     True       True            True        True
# 4                     True       True            True        True
# 5                     True       True            True        True
# 6                     True       True            True        True
# 7                     True       True            True        True
# 8                     True       True            True        True
# 9                    False       True            True        True
# 10                   False       True            True       False
# 11                   False       True            True        True
# 12                   False       True            True        True
# ...

# %%
import numpy as np
rows,cols=np.where(comparison_values==False)

# %%
for item in zip(rows,cols):
    df1.iloc[item[0], item[1]] = '{} --> {}'.format(df1.iloc[item[0], item[1]],df2.iloc[item[0], item[1]])

# %%
df1
# Out:
#                        Variable / Field Name              Form Name  \
# 0                                         id                biodata
# 1                                    hosp_id                biodata
# 2                                      depid                biodata
# 3                                 date_today                biodata
# 4                                       ipno                biodata
# 5                                  age_years                biodata
# 6                                   age_mths                biodata
# 7                              age_less1mnth                biodata
# 8                                   age_days                biodata
# 9                       date_adm --> res_loc                biodata
# 10                      ref_hosp --> res_dst                biodata
# 11                ref_hosp_spec --> date_adm                biodata
# 12                   readm_hosp --> ref_hosp                biodata
# ...

# %%
df1.dropna(axis=1, how='all')
# Out:
#                        Variable / Field Name              Form Name  \
# 0                                         id                biodata
# 1                                    hosp_id                biodata
# 2                                      depid                biodata
# 3                                 date_today                biodata
# 4                                       ipno                biodata
# 5                                  age_years                biodata
# 6                                   age_mths                biodata
# 7                              age_less1mnth                biodata
# 8                                   age_days                biodata
# 9                       date_adm --> res_loc                biodata
# 10                      ref_hosp --> res_dst                biodata
# 11                ref_hosp_spec --> date_adm                biodata
# 12                   readm_hosp --> ref_hosp                biodata
# ...

# %%
df1.columns
# Out:
# Index(['Variable / Field Name', 'Form Name', 'Section Header', 'Field Type',
#        'Field Label', 'Choices, Calculations, OR Slider Labels', 'Field Note',
#        'Text Validation Type OR Show Slider Number', 'Text Validation Min',
#        'Text Validation Max', 'Identifier?',
#        'Branching Logic (Show field only if...)', 'Required Field?',
#        'Custom Alignment', 'Question Number (surveys only)',
#        'Matrix Group Name', 'Matrix Ranking?', 'Field Annotation'],
#       dtype='object')

# %%
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])\
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])
#df1[['Field Type','New_FieldType']]   = pd.DataFrame([ x.split('-->') for x in df1['Field Type'].tolist() ])

#df1

# %%
df1[['Section Header','New_Section Header']] =  df1['Section Header'].str.split('-->',expand=True)
df1[['Form Name','New_formName']] =  df1['Form Name'].str.split('-->',expand=True)
df1[['Variable / Field Name','New_fieldName']] =  df1['Variable / Field Name'].str.split('-->',expand=True)
df1[['Field Type','New_FieldType']] =  df1['Field Type'].str.split('-->',expand=True)
df1[['Field Label','New_FieldLabel']] = df1['Field Label'].str.split('-->',expand=True)
df1[['Choices, Calculations, OR Slider Labels','New_Choices, Calculations, OR Slider Labels']] = df1['Choices, Calculations, OR Slider Labels'].str.split('-->',expand=True)
df1[['Field Note','New_FieldNote']] =  df1['Field Note'].str.split('-->',expand=True)
df1[['Text Validation Type OR Show Slider Number','New_Text Validation Type OR Show Slider Number']] = df1['Text Validation Type OR Show Slider Number'].str.split('-->',expand=True)
df1[['Text Validation Min','New_Text Validation Min']] = df1['Text Validation Min'].str.split('-->',expand=True)
df1[['Text Validation Max','New_Text Validation Max']] =  df1['Text Validation Max'].str.split('-->',expand=True)
#df1[['Identifier?','New_Identifier?']] = df1['Identifier?'].astype(str).str.split('-->',expand=True)
df1[['Branching Logic (Show field only if...)','New_Branching Logic (Show field only if)']] =  df1['Branching Logic (Show field only if...)'].str.split('-->',expand=True)

df1[['Required Field?','New_Required Field?']] =  df1['Required Field?'].str.split('-->',expand=True)
df1[['Custom Alignment','New_Custom Alignment']] =  df1['Custom Alignment'].str.split('-->',expand=True)
#df1[['Question Number (surveys only)','New_Question Number (surveys only)']] =  df1['Question Number (surveys only)'].str.split('-->',expand=True)

#df1[['Matrix Group Name)','New_Matrix Group Name']] = df1['Matrix Group Name'].str.split('-->',expand=True)
#df1[['Matrix Ranking?','New_Matrix Ranking?']] = df1['Matrix Ranking?'].str.split('-->',expand=True)
#df1[['Field Annotation','New_Field Annotation']] = ddf1['Field Annotation'].str.split('-->',expand=True)

# %%
df1
# Out:
#     Variable / Field Name              Form Name  \
# 0                      id                biodata
# 1                 hosp_id                biodata
# 2                   depid                biodata
# 3              date_today                biodata
# 4                    ipno                biodata
# 5               age_years                biodata
# 6                age_mths                biodata
# 7           age_less1mnth                biodata
# 8                age_days                biodata
# 9               date_adm                 biodata
# 10              ref_hosp                 biodata
# 11         ref_hosp_spec                 biodata
# 12            readm_hosp                 biodata
# 13                weight                 biodata
# 14                height                 biodata
# 15                   whz                 biodata
# 16                  muac                 biodata
# 17             child_sex                 biodata
# ...

# %%
df1.to_csv("Differeb.csv", index=False)

# %%
df1['Form Name'] == df1['New_FieldNote']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# 286    False
# 287    False
# 288    False
# 289    False
# 290    False
# 291    False
# 292    False
# 293    False
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# 303    False
# 304    False
# 305    False
# 306    False
# 307    False
# 308    False
# 309    False
# 310    False
# Length: 311, dtype: bool

# %%
#df = df1.reindex('Variable / Field Name', 'Form Name', 'Section Header', 'Field Type',
       #'Field Label', 'Choices, Calculations, OR Slider Labels', 'Field Note',
       #'Text Validation Type OR Show Slider Number', 'Text Validation Min',
       #'Text Validation Max', 'Identifier?',
       #'Branching Logic (Show field only if...)', 'Required Field?',
      # 'Custom Alignment', 'Question Number (surveys only)',
       #'Matrix Group Name', 'Matrix Ranking?', 'Field Annotation',
        'New_fieldName','New_formName','New_Section Header',
               # 'New_FieldType','New_FieldLabel', 'New_Choices, Calculations, OR Slider Labels',
       #'New_FieldNote', 'New_Text Validation Type OR Show Slider Number',
       #'New_Text Validation Min', 'New_Text Validation Max',
       #'New_Branching Logic (Show field only if)', 'New_Required Field?',
       #'New_Custom Alignment', axis=1)

# %%
dfo=dff.reindex(['Variable / Field Name','New_fieldName', 'Form Name', 'New_formName','Section Header', 'New_Section Header',
                 'Field Type', 'New_FieldType', 'Field Label', 'New_FieldLabel', 'Choices, Calculations, OR Slider Labels', 
                 'New_Choices, Calculations, OR Slider Labels', 'Field Note', 'New_FieldNote','Text Validation Type OR Show Slider Number',
                 'New_Text Validation Type OR Show Slider Number',
                 'Wavenumber_one', 'Wavenumber_last', 'Min_absorbance', 'Max_Absorbance'], axis=1)

# %%
df1['Field Label', 'New_FieldLabel'] = df1['Field Label'].str.split('-->').str[1]

df1['Text Validation Min','New_Text Validation Min']= df1['Text Validation Min'].str.split('-->').str[1]
df1['Section Header','New_Section Header'] = df1['Section Header'].str.split('-->').str[1]
df1['Form Name','New_formName'] = df1['Form Name'].str.split('-->').str[1]
df1['Variable / Field Name','New_fieldName'] = df1['Variable / Field Name'].str.split('-->').str[1]
df1['Field Type','New_FieldType'] = df1['Field Type'].str.split('-->').str[1]
df1['Field Label','New_FieldLabel'] = df1['Field Label'].str.split('-->').str[1]
df1['Choices, Calculations, OR Slider Labels','New_Choices, Calculations, OR Slider Labels'] = df1['Choices, Calculations, OR Slider Labels'].str.split('-->').str[1]
df1[['Field Note','New_FieldNote']] = df1['Field Note'].str.split('-->',expand=True)

df1['Text Validation Type OR Show Slider Number','New_Text Validation Type OR Show Slider Number'] = df1['Text Validation Type OR Show Slider Number'].str.split('-->').str[1]

df1['Text Validation Max','New_Text Validation Max'] = df1['Text Validation Max'].str.split('-->').str[1]
df1['Identifier?','New_Identifier?'] = df1['Identifier?'].str.split('-->').str[1]
df1['Branching Logic (Show field only if...)','New_Branching Logic (Show field only if)'] = df1['Branching Logic (Show field only if...)'].str.split('-->').str[1]
df1['Required Field?','New_Required Field?'] = df1['Required Field?'].str.split('-->').str[1]
df1['Custom Alignment','New_Custom Alignment'] = df1['Custom Alignment'].str.split('-->').str[1]
#df1['Question Number (surveys only)','New_Question Number (surveys only)'] = df1['Question Number (surveys only)'].str.split('-->').str[1]

#df1['Matrix Group Name)','New_Matrix Group Name'] =df1['Matrix Group Name'].str.split('-->').str[1]
#df1['Matrix Ranking?','New_Matrix Ranking?'] = df1['Matrix Ranking?'].str.split('-->').str[1]
#df1['Field Annotation','New_Field Annotation'] = df1['Field Annotation'].str.split('-->').str[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-185-72d3f9678165> in <module>
#      13
#      14 df1['Text Validation Max','New_Text Validation Max'] = df1['Text Validation Max'].str.split('-->').str[1]
# ---> 15 df1['Identifier?','New_Identifier?'] = df1['Identifier?'].str.split('-->').str[1]
#      16 df1['Branching Logic (Show field only if...)','New_Branching Logic (Show field only if)'] = df1['Branching Logic (Show field only if...)'].str.split('-->').str[1]
#      17 df1['Required Field?','New_Required Field?'] = df1['Required Field?'].str.split('-->').str[1]
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
# ...

# %%
df1
# Out:
#                        Variable / Field Name              Form Name  \
# 0                                         id                biodata
# 1                                    hosp_id                biodata
# 2                                      depid                biodata
# 3                                 date_today                biodata
# 4                                       ipno                biodata
# 5                                  age_years                biodata
# 6                                   age_mths                biodata
# 7                              age_less1mnth                biodata
# 8                                   age_days                biodata
# 9                       date_adm --> res_loc                biodata
# 10                      ref_hosp --> res_dst                biodata
# 11                ref_hosp_spec --> date_adm                biodata
# 12                   readm_hosp --> ref_hosp                biodata
# ...

# %%
df1['Section Header','New_Section Header'] = df1['Section Header'].str.split('-->').str[1]
df1['Form Name','New_formName'] = df1['Form Name'].str.split('-->').str[1]
df1['Variable / Field Name','New_fieldName'] = df1['Variable / Field Name'].str.split('-->').str[1]
df1['Field Type','New_FieldType'] = df1['Field Type'].str.split('-->').str[1]
df1['Field Label','New_FieldLabel'] = df1['Field Label'].str.split('-->').str[1]
df1['Choices, Calculations, OR Slider Labels','New_Choices, Calculations, OR Slider Labels'] = df1['Choices, Calculations, OR Slider Labels'].str.split('-->').str[1]
df1[['Field Note','New_FieldNote']] = df1['Field Note'].str.split('-->',expand=True)
df1['Text Validation Type OR Show Slider Number','New_Text Validation Type OR Show Slider Number'] = df1['Text Validation Type OR Show Slider Number'].str.split('-->').str[1]

df1['Text Validation Max','New_Text Validation Max'] = df1['Text Validation Max'].str.split('-->').str[1]
df1['Identifier?','New_Identifier?'] = df1['Identifier?'].str.split('-->').str[1]
df1['Branching Logic (Show field only if...)','New_Branching Logic (Show field only if)'] = df1['Branching Logic (Show field only if...)'].str.split('-->').str[1]

df1['Required Field?','New_Required Field?'] = df1['Required Field?'].str.split('-->').str[1]
df1['Custom Alignment','New_Custom Alignment'] = df1['Custom Alignment'].str.split('-->').str[1]
df1['Question Number (surveys only)','New_Question Number (surveys only)'] = df1['Question Number (surveys only)'].str.split('-->').str[1]

df1['Matrix Group Name)','New_Matrix Group Name'] =df1['Matrix Group Name'].str.split('-->').str[1]
df1['Matrix Ranking?','New_Matrix Ranking?'] = df1['Matrix Ranking?'].str.split('-->').str[1]
df1['Field Annotation','New_Field Annotation'] = df1['Field Annotation'].str.split('-->').str[1]

# %%
compare.matches(ignore_extra_columns=False)
# Out:
# False

# %%
# This method prints out a human-readable report summarizing and sampling differences
print(type(compare.report()))
# Out:
# <class 'str'>

# %%
import glob
import os
import pandas as pd

# %%
# the path to your csv file directory
mycsvdir = 'C:/Users/lmumelo/Downloads/Compare_obj/cin_dicts'

# %%
# get all the csv files in that directory (assuming they have the extension .csv)
csvfiles = glob.glob(os.path.join(mycsvdir, '*.csv'))

# %%
# loop through the files and read them in with pandas
dataframes = []  # a list to hold all the individual pandas DataFrames
for csvfile in csvfiles:
    df = pd.read_csv(csvfile)
    dataframes.append(df)

# %%
dataframes[1]
# Out:
#     Variable / Field Name              Form Name       Section Header  \
# 0                      id                biodata                  NaN
# 1              doc_source                biodata                  NaN
# 2          surgical_burns                biodata                  NaN
# 3                date_adm                biodata                  NaN
# 4          date_discharge                biodata                  NaN
# 5                 hosp_id                biodata                  NaN
# 6            leave_period                biodata                  NaN
# 7                  random                biodata                  NaN
# 8                   depid                biodata                  NaN
# 9              date_today                biodata                  NaN
# 10              timestamp                biodata                  NaN
# 11                   ipno                biodata                  NaN
# ...

# %%
compare = datacompy.Compare(dataframes[1],dataframes[2],on_index=True)

# %%
compare.matches(ignore_extra_columns=False)
# Out:
# False

# %%
# This method prints out a human-readable report summarizing and sampling differences
print(type(compare.report()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ed3ebece15cf> in <module>
#       1 # This method prints out a human-readable report summarizing and sampling differences
# ----> 2 print(type(compare.report()))
#
# NameError: name 'compare' is not defined

# %%
#get columns unique to df1
compare.df2_unq_columns()
# Out:
# set()

# %%
compare.df2_unq_rows
# Out:
#     variable / field name              form name section header field type  \
# 442          rx_free_text  discharge_information            NaN       text
#
#                                field label  \
# 442  Other discharge treatments not listed
#
#     choices, calculations, or slider labels field note  \
# 442                                     NaN        NaN
#
#     text validation type or show slider number text validation min  \
# 442                                        NaN                 NaN
#
#      text validation max  identifier? branching logic (show field only if...)  \
# 442                  NaN          NaN                    [rx_nt_listed] = '1'
#
#     required field? custom alignment  question number (surveys only)  \
# 442             NaN               RH                             NaN
#
#     matrix group name  matrix ranking? field annotation
# 442               NaN              NaN              NaN

# %%
datacompy.core.render(df2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-8bd40dccd421> in <module>
# ----> 1 datacompy.core.render(df2)
#
# C:\Anaconda3\lib\site-packages\datacompy\core.py in render(filename, *fields)
#     579     """
#     580     this_dir = os.path.dirname(os.path.realpath(__file__))
# --> 581     with open(os.path.join(this_dir, "templates", filename)) as file_open:
#     582         return file_open.read().format(*fields)
#     583
#
# C:\Anaconda3\lib\ntpath.py in join(path, *paths)
#     113         return result_drive + result_path
#     114     except (TypeError, AttributeError, BytesWarning):
# --> 115         genericpath._check_arg_types('join', path, *paths)
#     116         raise
#     117
#
# C:\Anaconda3\lib\genericpath.py in _check_arg_types(funcname, *args)
#     147         else:
# ...
